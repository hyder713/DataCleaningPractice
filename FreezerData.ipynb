# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
df= pd.read_csv("FreezerData.csv",skiprows=[0,1,2,4])

# %%
df.rename(columns={"\t1-¡ãF":"Volume_Center","\t3-¡ãF":"Top_Center","\t5-¡ãF":"Top_Wall"},inplace=True)

# %%
df['TIME']=df['TIME'].astype(str)

# %%
ax= plt.gca()
plt.rcParams["figure.figsize"]= (20,10)
df.plot(kind='line',x='TIME', y='Volume_Center', ax=ax, fontsize=10)
df.plot(kind='line', x='TIME',y='Top_Center', color='red', ax=ax)
df.plot(kind='line', x='TIME', y='Top_Wall', color='orange', ax=ax)

plt.show()

# %%
df.describe()
# Out:
#                 SN  Volume_Center   Top_Center     Top_Wall
# count  3926.000000    3926.000000  3926.000000  3926.000000
# mean   1964.500000     -41.855425   -42.353337   -43.574325
# std    1133.482907      65.703617    68.523961    69.012937
# min       2.000000     -97.700000  -101.000000  -103.100000
# 25%     983.250000     -96.500000   -99.500000  -101.200000
# 50%    1964.500000     -95.000000   -98.100000   -99.700000
# 75%    2945.750000      32.900000    32.900000    34.100000
# max    3927.000000      71.000000    71.200000    70.700000
